# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
     

df1 = pd.read_csv('apipop.csv')
print(df1)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df1.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df1.isna()
# Out:
#      Country Name  Country Code  Indicator Name  Indicator Code   1960   1961  \
# 0           False         False           False           False  False  False
# 1           False         False           False           False  False  False
# 2           False         False           False           False  False  False
# 3           False         False           False           False  False  False
# 4           False         False           False           False  False  False
# ..            ...           ...             ...             ...    ...    ...
# 261         False         False           False           False  False  False
# 262         False         False           False           False  False  False
# 263         False         False           False           False  False  False
# 264         False         False           False           False  False  False
# 265         False         False           False           False  False  False
#
# ...

# %%
df1 = df1.drop('2023', axis=1)
df1 = df1.drop('Indicator Name', axis=1)
df1 = df1.drop('Indicator Code', axis=1)
df1.isna()
# Out:
#      Country Name  Country Code   1960   1961   1962   1963   1964   1965  \
# 0           False         False  False  False  False  False  False  False
# 1           False         False  False  False  False  False  False  False
# 2           False         False  False  False  False  False  False  False
# 3           False         False  False  False  False  False  False  False
# 4           False         False  False  False  False  False  False  False
# ..            ...           ...    ...    ...    ...    ...    ...    ...
# 261         False         False  False  False  False  False  False  False
# 262         False         False  False  False  False  False  False  False
# 263         False         False  False  False  False  False  False  False
# 264         False         False  False  False  False  False  False  False
# 265         False         False  False  False  False  False  False  False
#
#       1966   1967  ...   2013   2014   2015   2016   2017   2018   2019  \
# ...

# %%
df1.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1960            2
# 1961            2
# 1962            2
#                ..
# 2018            1
# 2019            1
# 2020            1
# 2021            1
# 2022            1
# Length: 65, dtype: int64

# %%
df1.dropna().isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 1960            0
# 1961            0
# 1962            0
#                ..
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# 2022            0
# Length: 65, dtype: int64

# %%
df1.dropna()
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54608.0      55811.0
# 1    Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                    Afghanistan          AFG    8622466.0    8790140.0
# 3     Africa Western and Central          AFW   97256290.0   99314028.0
# 4                         Angola          AGO    5357195.0    5441333.0
# ..                           ...          ...          ...          ...
# 261                       Kosovo          XKX     947000.0     966000.0
# 262                  Yemen, Rep.          YEM    5542459.0    5646668.0
# 263                 South Africa          ZAF   16520441.0   16989464.0
# 264                       Zambia          ZMB    3119430.0    3219451.0
# 265                     Zimbabwe          ZWE    3806310.0    3925952.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
df1.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172860e+08  1.188956e+08  1.210661e+08  1.237484e+08  1.264530e+08
# std    3.695500e+08  3.740958e+08  3.808121e+08  3.895098e+08  3.982497e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291965e+08  1.320558e+08  1.349134e+08  1.378513e+08  1.408944e+08
# ...

# %%
df2 = pd.read_csv("Metadata.csv")
df2
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
df2.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
df2.tail()
# Out:
#     Country Code                      Region          IncomeGroup  \
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName
# 260                                                NaN        Kosovo
# 261  The World Bank systematically assesses the app...   Yemen, Rep.
# 262  Fiscal year end: March 31; reporting period fo...  South Africa
# 263  National accounts data were rebased to reflect...        Zambia
# 264  National Accounts data are reported in Zimbabw...      Zimbabwe

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  265 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   SpecialNotes  126 non-null    object
#  4   TableName     265 non-null    object
# dtypes: object(5)
# memory usage: 10.5+ KB

# %%
df2.isna()
# Out:
#      Country Code  Region  IncomeGroup  SpecialNotes  TableName
# 0           False   False        False          True      False
# 1           False    True         True         False      False
# 2           False   False        False         False      False
# 3           False    True         True         False      False
# 4           False   False        False         False      False
# ..            ...     ...          ...           ...        ...
# 260         False   False        False          True      False
# 261         False   False        False         False      False
# 262         False   False        False         False      False
# 263         False   False        False         False      False
# 264         False   False        False         False      False
#
# [265 rows x 5 columns]

# %%
import pandas as pd

# Assuming df2 is already defined
# Check and drop 'Unnamed: 5' column if it exists
if 'Unnamed: 5' in df2.columns:
    df2 = df2.drop('Unnamed: 5', axis=1)

# Check and drop 'SpecialNotes' column if it exists
if 'SpecialNotes' in df2.columns:
    df2 = df2.drop('SpecialNotes', axis=1)

# Display missing values in the DataFrame
print(df2.isna().sum())
# Out:
# Country Code     0
# Region          48
# IncomeGroup     49
# TableName        0
# dtype: int64

# %%
df2.dropna().isnull().sum()
# Out:
# Country Code    0
# Region          0
# IncomeGroup     0
# TableName       0
# dtype: int64

# %%
df2.dropna()
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 2            AFG                  South Asia           Low income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# 5            ALB       Europe & Central Asia  Upper middle income
# 6            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#         TableName
# 0           Aruba
# 2     Afghanistan
# 4          Angola
# 5         Albania
# 6         Andorra
# ..            ...
# 260        Kosovo
# ...

# %%
df2.describe()
# Out:
#        Country Code                 Region  IncomeGroup TableName
# count           265                    217          216       265
# unique          265                      7            4       265
# top             ABW  Europe & Central Asia  High income     Aruba
# freq              1                     58           82         1

# %%
df = (df1.dropna().merge(df2.dropna(), on='Country Code').rename(columns={'Country Name': 'Country', 'IncomeGroup':'Income'}))
print(df)
# Out:
#           Country Country Code        1960        1961        1962  \
# 0           Aruba          ABW     54608.0     55811.0     56682.0
# 1     Afghanistan          AFG   8622466.0   8790140.0   8969047.0
# 2          Angola          AGO   5357195.0   5441333.0   5521400.0
# 3         Albania          ALB   1608800.0   1659800.0   1711319.0
# 4         Andorra          AND      9443.0     10216.0     11014.0
# ..            ...          ...         ...         ...         ...
# 210        Kosovo          XKX    947000.0    966000.0    994000.0
# 211   Yemen, Rep.          YEM   5542459.0   5646668.0   5753386.0
# 212  South Africa          ZAF  16520441.0  16989464.0  17503133.0
# 213        Zambia          ZMB   3119430.0   3219451.0   3323427.0
# 214      Zimbabwe          ZWE   3806310.0   3925952.0   4049778.0
#
#            1963        1964        1965        1966        1967  ...  \
# 0       57475.0     58178.0     58782.0     59291.0     59522.0  ...
# ...

# %%
df = df.melt( id_vars=['Region','Country','Income'],
            value_vars=[str(year) for year in range(1960, 2023)],
            var_name='Year',
            value_name='Population')
df
# Out:
#                            Region       Country               Income  Year  \
# 0       Latin America & Caribbean         Aruba          High income  1960
# 1                      South Asia   Afghanistan           Low income  1960
# 2              Sub-Saharan Africa        Angola  Lower middle income  1960
# 3           Europe & Central Asia       Albania  Upper middle income  1960
# 4           Europe & Central Asia       Andorra          High income  1960
# ...                           ...           ...                  ...   ...
# 13540       Europe & Central Asia        Kosovo  Upper middle income  2022
# 13541  Middle East & North Africa   Yemen, Rep.           Low income  2022
# 13542          Sub-Saharan Africa  South Africa  Upper middle income  2022
# 13543          Sub-Saharan Africa        Zambia  Lower middle income  2022
# 13544          Sub-Saharan Africa      Zimbabwe  Lower middle income  2022
#
#        Population
# 0         54608.0
# 1       8622466.0
# ...

# %%
df.isna().sum()
# Out:
# Region        0
# Country       0
# Income        0
# Year          0
# Population    0
# dtype: int64

# %% [markdown]
# Performing EDA

# %%
fig, ((a1, a2), (a3, a4)) = plt.subplots(nrows=2,ncols=2,figsize=(20, 10),gridspec_kw={'width_ratios': [2,1]})

sns.countplot(data=df, x='Region', ax=a1, color='BLACK')
a1.set_title('Count of Regions')

sns.countplot(data=df, x='Income', ax=a2)
a2.set_title('Count of Income types')

sns.barplot(data=df, x='Region', y='Population', ax=a3, color='BLACK')
a3.set_title('Population by Region')

sns.barplot(data=df, x='Income', y='Population', ax=a4)
a4.set_title('Population by Income types')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
sns.barplot(data=df, x='Region', y='Population', estimator=sum)
plt.title('Population by Region (based on sum of values)')
plt.xlabel('Region')
plt.ylabel('Total Population')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Income', y='Population', data=df, estimator=sum)
plt.title('Total Population by Income Level (based on sum of values)')
plt.xlabel('Income Level')
plt.ylabel('Total Population')
plt.show()

# %%
plt.figure(figsize=(50, 6))
sns.barplot(x='Year', y='Population', data=df, estimator=sum)
plt.title('Total Population by Year')
plt.xlabel('Year')
plt.ylabel('Total Population')
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x='Region', y='Population', hue='Income', data=df, estimator=sum)
plt.title('Total Population by Region and Income Level')
plt.xlabel('Region')
plt.ylabel('Total Population')
plt.yscale('log')
plt.legend(title='Income Level')
plt.show()
# some gaps are there as the values are very low!

# %%
g = sns.displot(
    data=df,
    x='Population',
    col='Region',
    hue='Region',
    kind='hist',
    kde=True,
    log_scale=True)
g.set_titles(col_template='{col_name} Region')
plt.show()

# %%
g = sns.displot(
    data=df,
    x='Population',
    col='Income',
    hue='Income',
    kind='hist',
    kde=True,
    log_scale=True)
g.set_titles(col_template='{col_name} Income Level')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Population'], bins=10, kde=True, log_scale=True)
plt.title('Distribution of Population (Log Scale)')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()
